# %%
from pig_game import Player

# %%
josh = Player()

# %%
result = josh.game()

# %%
print(result)
# Out:
# 26

# %%
from pig_game import Three_Rolls_Player

# %%
arlo = Three_Rolls_Player()

# %%
result = arlo.game()

# %%
print(result)
# Out:
# 71

# %%
from pig_game import Four_Rolls_Player

# %%
bea = Four_Rolls_Player()

# %%
result4 = bea.game()

# %%
print(result4)
# Out:
# 58

# %%
# %matplotlib inline

# %%
from pig_game import n_trials

# %%
trial_results = n_trials(1000, Player)

# %%
print(trial_results)
# Out:
# (23.471, 5.213092684322363, 38, 5, [26, 27, 16, 34, 19, 26, 22, 26, 21, 29, 25, 20, 16, 28, 27, 30, 22, 21, 28, 13, 15, 17, 27, 25, 20, 20, 11, 19, 24, 20, 25, 30, 20, 31, 22, 22, 27, 28, 18, 22, 30, 24, 23, 28, 23, 35, 22, 13, 28, 30, 22, 23, 17, 17, 33, 13, 22, 25, 31, 25, 18, 24, 15, 26, 19, 24, 17, 28, 17, 19, 25, 31, 24, 16, 27, 32, 23, 29, 25, 24, 22, 28, 16, 26, 24, 16, 29, 24, 21, 30, 28, 22, 17, 19, 24, 18, 19, 24, 21, 22, 20, 24, 35, 26, 23, 27, 14, 21, 27, 32, 22, 20, 19, 16, 16, 25, 20, 26, 25, 25, 19, 29, 25, 20, 25, 16, 24, 24, 17, 29, 19, 26, 25, 28, 19, 22, 31, 22, 25, 23, 31, 24, 21, 26, 32, 29, 22, 23, 17, 22, 17, 28, 24, 22, 24, 29, 20, 16, 32, 18, 26, 25, 18, 20, 20, 23, 24, 30, 16, 31, 22, 23, 17, 14, 25, 17, 28, 18, 24, 28, 25, 15, 25, 29, 14, 18, 20, 31, 19, 22, 24, 27, 35, 14, 23, 25, 29, 26, 28, 26, 25, 29, 31, 17, 29, 25, 13, 26, 29, 22, 33, 16, 23, 28, 29, 24, 24, 23, 20, 35, 29, 27, 22, 22, 23, 20, 19, 26, 28, 25, 17, 19, 24, 14, 23, 12, 36, 22, 20, 22, 22
# ...

# %%
from pig_game import Two_Rolls_Player
from pig_game import Five_Rolls_Player
from pig_game import Six_Rolls_Player
from pig_game import Roll_Until_10_Player
from pig_game import Roll_Until_15_Player
from pig_game import Roll_Until_20_Player
from pig_game import Roll_Until_30_Player
from pig_game import Roll_Until_40_Player

# %%
trial_player = n_trials(1000, Player)

# %%
trial_2_roll_player = n_trials(1000, Two_Rolls_Player)

# %%
trial_3_roll_player = n_trials(1000, Three_Rolls_Player)

# %%
trial_4_roll_player = n_trials(1000, Four_Rolls_Player)

# %%
trial_5_roll_player = n_trials(1000, Five_Rolls_Player)
trial_6_roll_player = n_trials(1000, Six_Rolls_Player)

# %%
print((trial_player)[:4])
print((trial_2_roll_player)[:4])
print((trial_3_roll_player)[:4])
print((trial_4_roll_player)[:4])
print((trial_5_roll_player)[:4])
print((trial_6_roll_player)[:4])
# Out:
# (23.39, 5.198165149446574, 38, 3)
# (38.984, 10.982001108557053, 66, 7)
# (49.488, 16.4088118127153, 102, 0)
# (53.875, 21.501481081281092, 112, 0)
# (55.535, 26.216523054766075, 130, 0)
# (55.321, 31.217246442879546, 154, 0)

# %%
trial_roll_until_10_player = n_trials(1000, Roll_Until_10_Player)
trial_roll_until_15_player = n_trials(1000, Roll_Until_15_Player)
trial_roll_until_20_player = n_trials(1000, Roll_Until_20_Player)
trial_roll_until_30_player = n_trials(1000, Roll_Until_30_Player)
trial_roll_until_40_player = n_trials(1000, Roll_Until_40_Player)

# %%
print((trial_roll_until_10_player)[:4])
print((trial_roll_until_15_player)[:4])
print((trial_roll_until_20_player)[:4])
print((trial_roll_until_30_player)[:4])
print((trial_roll_until_40_player)[:4])
# Out:
# (48.466, 15.212306145297571, 95, 0)
# (55.986, 22.21362755718321, 123, 0)
# (56.919, 27.695947438289675, 147, 0)
# (53.367, 35.77801528002046, 165, 0)
# (45.594, 39.496672659239934, 173, 0)

# %%
len(trial_player)
# Out:
# 5

# %%
import matplotlib.pyplot as plt

# %%
plt.hist((trial_player[4]), bins=15)
plt.xlabel("Score")
plt.ylabel("frequency")
plt.title("Scores for Player Rolling Once Only")
plt.text(2, 150, 'Mean: 23.39, StDev: 5.2')
plt.show()

# %%
plt.hist((trial_2_roll_player[4]), bins=15)
plt.xlabel("Score")
plt.ylabel("frequency")
plt.title("Scores for Player Rolling Twice Only")
plt.text(2, 130, 'Mean: 39.0, StDev: 11.0')
plt.show()

# %%
plt.hist((trial_3_roll_player[4]), bins=15)
plt.xlabel("Score")
plt.ylabel("frequency")
plt.title("Scores for Player Rolling Three Times Only")
plt.text(70, 150, 'Mean: 49.5, StDev: 16.4')
plt.show()

# %%
plt.hist((trial_4_roll_player[4]), bins=15)
plt.xlabel("Score")
plt.ylabel("frequency")
plt.title("Scores for Player Rolling Four Times Only")
plt.text(70, 150, 'Mean: 53.9, StDev: 21.5')
plt.show()

# %%
plt.hist((trial_5_roll_player[4]), bins=20)
plt.xlabel("Score")
plt.ylabel("frequency")
plt.title("Scores for Player Rolling Five Times Only")
plt.text(80, 120, 'Mean: {}, StDev: {}'.format(trial_5_roll_player[0], \
                                               round((trial_5_roll_player[1]), 3)))
plt.show()

# %%
plt.hist((trial_6_roll_player[4]), bins=20)
plt.xlabel("Score")
plt.ylabel("frequency")
plt.title("Scores for Player Rolling Five Times Only")
plt.text(80, 150, 'Mean: {}, StDev: {}'.format(trial_6_roll_player[0], \
                                               round((trial_6_roll_player[1]), 3)))
plt.show()

# %%
plt.hist((trial_roll_until_10_player[4]), bins=15)
plt.xlabel("Score")
plt.ylabel("frequency")
plt.title("Scores for Player Rolling to Get to 10")
plt.text(70, 100, 'Mean: {}, StDev: {}'.format(trial_roll_until_10_player[0], \
                                               round((trial_roll_until_10_player[1]), 3)))
plt.show()

# %%
plt.hist((trial_roll_until_15_player[4]), bins=15)
plt.xlabel("Score")
plt.ylabel("frequency")
plt.title("Scores for Player Rolling to Get to 15")
plt.text(80, 120, 'Mean: {}, StDev: {}'.format(trial_roll_until_15_player[0], \
                                               round((trial_roll_until_15_player[1]), 3)))
plt.show()

# %%
plt.hist((trial_roll_until_20_player[4]), bins=15)
plt.xlabel("Score")
plt.ylabel("frequency")
plt.title("Scores for Player Rolling to Get to 20")
plt.text(70, 200, 'Mean: {}, StDev: {}'.format(trial_roll_until_20_player[0], \
                                               round((trial_roll_until_20_player[1]), 3)))
plt.show()

# %%
plt.hist((trial_roll_until_30_player[4]), bins=20)
plt.xlabel("Score")
plt.ylabel("frequency")
plt.title("Scores for Player Rolling to Get to 30")
plt.text(70, 200, 'Mean: {}, StDev: {}'.format(trial_roll_until_30_player[0], \
                                               round((trial_roll_until_30_player[1]), 3)))
plt.show()

# %%
plt.hist((trial_roll_until_40_player[4]), bins=20)
plt.xlabel("Score")
plt.ylabel("frequency")
plt.title("Scores for Player Rolling to Get to 40")
plt.text(70, 250, 'Mean: {}, StDev: {}'.format(trial_roll_until_40_player[0], \
                                               round((trial_roll_until_40_player[1]), 3)))
plt.show()

# %%
list_of_trial_results = [
        trial_roll_until_10_player,
        trial_roll_until_15_player,
        trial_roll_until_20_player,
        trial_roll_until_30_player,
        trial_roll_until_40_player,
        trial_player,
        trial_2_roll_player,
        trial_3_roll_player,
        trial_4_roll_player,
        trial_5_roll_player,
        trial_6_roll_player    
    ]

# %%
averages = [i[0] for i in list_of_trial_results]

# %%
print(averages)
# Out:
# [48.466, 55.986, 56.919, 53.367, 45.594, 23.39, 38.984, 49.488, 53.875, 55.535, 55.321]

# %%
stdevs = [i[1] for i in list_of_trial_results]

# %%
print(stdevs)
# Out:
# [15.212306145297571, 22.21362755718321, 27.695947438289675, 35.77801528002046, 39.496672659239934, 5.198165149446574, 10.982001108557053, 16.4088118127153, 21.501481081281092, 26.216523054766075, 31.217246442879546]

# %%
high_range = [[i[2] for i in list_of_trial_results]]

# %%
print(high_range)
# Out:
# [[95, 123, 147, 165, 173, 38, 66, 102, 112, 130, 154]]

# %%
x1 = ['Try for 10', 'Try for 15', 'Try for 20', 'Try for 30', 'Try for 40', '1 Roll', \
      '2 Rolls', '3Rolls', '4Rolls', '5 Rolls', '6Rolls']
y1 = high_range
plt.scatter(range(11), y1)
plt.xticks(range(11), x1)
plt.xlabel("Strategy")
plt.ylabel("High Score in 1000 Trials")
plt.title("High Score Comparison of Rolling Strategies")

locs, labels = plt.xticks() #gets labels
plt.setp(labels, rotation=90)
plt.show()

# %%
x1 = ['Try for 10', 'Try for 15', 'Try for 20', 'Try for 30', 'Try for 40', '1 Roll', \
      '2 Rolls', '3Rolls', '4Rolls', '5 Rolls', '6Rolls']
y1 = stdevs
plt.scatter(range(11), y1)
plt.xticks(range(11), x1)
plt.xlabel("Strategy")
plt.ylabel("StDev of 1000 Trials")
plt.title("StDev Comparison of Rolling Strategies")

locs, labels = plt.xticks() #gets labels
plt.setp(labels, rotation=90)
plt.show()

# %%
x1 = ['Try for 10', 'Try for 15', 'Try for 20', 'Try for 30', 'Try for 40', '1 Roll', \
      '2 Rolls', '3Rolls', '4Rolls', '5 Rolls', '6Rolls']
y1 = averages
plt.plot(range(11), y1)
plt.xticks(range(11), x1)
plt.xlabel("Strategy")
plt.ylabel("Mean Score over 1000 Trials")
plt.title("Mean Score Comparison for 11 Rolling Strategies")

locs, labels = plt.xticks() #gets labels
plt.setp(labels, rotation=90)
plt.show()

# %% [markdown]
# The line chart above is not the best display of information compared to the previous scatter plots, so I will plot the same data with a scatter below.

# %%
x1 = ['Try for 10', 'Try for 15', 'Try for 20', 'Try for 30', 'Try for 40', '1 Roll', \
      '2 Rolls', '3Rolls', '4Rolls', '5 Rolls', '6Rolls']
y1 = averages
plt.scatter(range(11), y1)
plt.xticks(range(11), x1)
plt.xlabel("Strategy")
plt.ylabel("Mean Score over 1000 Trials")
plt.title("Mean Score Comparison for 11 Rolling Strategies")

locs, labels = plt.xticks() #gets labels
plt.setp(labels, rotation=90)
plt.show()

# %% [markdown]
# ###Appears that trying for 15 or 20 produce good results, as does 4 to 6 roll strategy.
# Maybe combining the logic would optimize.
# Roll up to 4 rolls, stop when you get to 20
# or, roll up to 3 rolls, stop when you get to 15

# %%
class Four_and_Twenty_Rolls_Player(Player):
    def roll_again_logic(self):
        if self.roll_count == 4:
            return False
        elif self.tally < 20:
            return True
        else:
            return False

# %%
trial_4_roll_20_player = n_trials(1000, Four_and_Twenty_Rolls_Player)

# %%
print((trial_4_roll_20_player)[:4])
# Out:
# (54.705, 20.846451725642652, 116, 0)

# %%
class Four_and_25_Rolls_Player(Player):
    def roll_again_logic(self):
        if self.roll_count == 4:
            return False
        elif self.tally < 25:
            return True
        else:
            return False

# %%
trial_4_roll_25_player = n_trials(1000, Four_and_25_Rolls_Player)

# %%
print((trial_4_roll_25_player)[:4])
# Out:
# (53.815, 21.3620952650744, 116, 0)

# %%
class Five_and_25_Rolls_Player(Player):
    def roll_again_logic(self):
        if self.roll_count == 5:
            return False
        elif self.tally < 25:
            return True
        else:
            return False

# %%
trial_5_roll_25_player = n_trials(1000, Five_and_25_Rolls_Player)

# %%
print((trial_5_roll_25_player)[:4])
# Out:
# (57.493, 26.710698463582197, 146, 0)

# %% [markdown]
# ###Data looks pretty similar for this player to the stop at 20 player.
# It depends on how much variation in your scores you can tolerate.
